# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score
from sklearn.model_selection import train_test_split
from word2number import w2n
from sklearn.ensemble import RandomForestClassifier
import seaborn as sns
import numpy as np

# %%
data=pd.read_csv('Traffic.csv')
data
# Out:
#              Time  Date Day of the week  CarCount  BikeCount  BusCount  \
# 0     12:00:00 AM    10         Tuesday        31          0         4
# 1     12:15:00 AM    10         Tuesday        49          0         3
# 2     12:30:00 AM    10         Tuesday        46          0         3
# 3     12:45:00 AM    10         Tuesday        51          0         2
# 4      1:00:00 AM    10         Tuesday        57          6        15
# ...           ...   ...             ...       ...        ...       ...
# 2971  10:45:00 PM     9        Thursday        16          3         1
# 2972  11:00:00 PM     9        Thursday        11          0         1
# 2973  11:15:00 PM     9        Thursday        15          4         1
# 2974  11:30:00 PM     9        Thursday        16          5         0
# 2975  11:45:00 PM     9        Thursday        14          3         1
#
#       TruckCount  Total Traffic Situation
# 0              4     39               low
# ...

# %%
data=data.drop('Total',axis=1)
data
# Out:
#              Time  Date Day of the week  CarCount  BikeCount  BusCount  \
# 0     12:00:00 AM    10         Tuesday        31          0         4
# 1     12:15:00 AM    10         Tuesday        49          0         3
# 2     12:30:00 AM    10         Tuesday        46          0         3
# 3     12:45:00 AM    10         Tuesday        51          0         2
# 4      1:00:00 AM    10         Tuesday        57          6        15
# ...           ...   ...             ...       ...        ...       ...
# 2971  10:45:00 PM     9        Thursday        16          3         1
# 2972  11:00:00 PM     9        Thursday        11          0         1
# 2973  11:15:00 PM     9        Thursday        15          4         1
# 2974  11:30:00 PM     9        Thursday        16          5         0
# 2975  11:45:00 PM     9        Thursday        14          3         1
#
#       TruckCount Traffic Situation
# 0              4               low
# 1              3               low
# ...

# %%
data=data.drop('Time',axis=1)
data
# Out:
#       Date Day of the week  CarCount  BikeCount  BusCount  TruckCount  \
# 0       10         Tuesday        31          0         4           4
# 1       10         Tuesday        49          0         3           3
# 2       10         Tuesday        46          0         3           6
# 3       10         Tuesday        51          0         2           5
# 4       10         Tuesday        57          6        15          16
# ...    ...             ...       ...        ...       ...         ...
# 2971     9        Thursday        16          3         1          36
# 2972     9        Thursday        11          0         1          30
# 2973     9        Thursday        15          4         1          25
# 2974     9        Thursday        16          5         0          27
# 2975     9        Thursday        14          3         1          15
#
#      Traffic Situation
# 0                  low
# 1                  low
# 2                  low
# 3                  low
# ...

# %%
x=data.drop('Traffic Situation',axis=1)
y=data['Traffic Situation']

# %%
x
# Out:
#       Date Day of the week  CarCount  BikeCount  BusCount  TruckCount
# 0       10         Tuesday        31          0         4           4
# 1       10         Tuesday        49          0         3           3
# 2       10         Tuesday        46          0         3           6
# 3       10         Tuesday        51          0         2           5
# 4       10         Tuesday        57          6        15          16
# ...    ...             ...       ...        ...       ...         ...
# 2971     9        Thursday        16          3         1          36
# 2972     9        Thursday        11          0         1          30
# 2973     9        Thursday        15          4         1          25
# 2974     9        Thursday        16          5         0          27
# 2975     9        Thursday        14          3         1          15
#
# [2976 rows x 6 columns]

# %%
x
# Out:
#       Date Day of the week  CarCount  BikeCount  BusCount  TruckCount
# 0       10         Tuesday        31          0         4           4
# 1       10         Tuesday        49          0         3           3
# 2       10         Tuesday        46          0         3           6
# 3       10         Tuesday        51          0         2           5
# 4       10         Tuesday        57          6        15          16
# ...    ...             ...       ...        ...       ...         ...
# 2971     9        Thursday        16          3         1          36
# 2972     9        Thursday        11          0         1          30
# 2973     9        Thursday        15          4         1          25
# 2974     9        Thursday        16          5         0          27
# 2975     9        Thursday        14          3         1          15
#
# [2976 rows x 6 columns]

# %%
y
# Out:
# 0          low
# 1          low
# 2          low
# 3          low
# 4       normal
#          ...
# 2971    normal
# 2972    normal
# 2973    normal
# 2974    normal
# 2975    normal
# Name: Traffic Situation, Length: 2976, dtype: object

# %%
le_day=LabelEncoder()
x['Day of the week']=le_day.fit_transform(x['Day of the week'])

# %%
x
# Out:
#       Date  Day of the week  CarCount  BikeCount  BusCount  TruckCount
# 0       10                5        31          0         4           4
# 1       10                5        49          0         3           3
# 2       10                5        46          0         3           6
# 3       10                5        51          0         2           5
# 4       10                5        57          6        15          16
# ...    ...              ...       ...        ...       ...         ...
# 2971     9                4        16          3         1          36
# 2972     9                4        11          0         1          30
# 2973     9                4        15          4         1          25
# 2974     9                4        16          5         0          27
# 2975     9                4        14          3         1          15
#
# [2976 rows x 6 columns]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=10)

# %%
model=RandomForestClassifier(n_estimators=47,random_state=34)
model.fit(x_train,y_train)
model.score(x_test,y_test)
# Out:
# 0.956989247311828

# %%
model.score(x_train,y_train)
# Out:
# 0.9995519713261649

# %%
from sklearn.metrics import confusion_matrix,classification_report

# %%
y_pred=model.predict(x_test)
confusion_matrix=confusion_matrix(y_test,y_pred)
confusion_matrix
# Out:
# array([[166,   7,   0,   0],
#        [  3,  63,   0,   7],
#        [  0,   0,  75,   3],
#        [ 11,   0,   1, 408]], dtype=int64)

# %%
data['Day of the week'].unique()
# Out:
# array(['Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday',
#        'Monday'], dtype=object)

# %%
Date=int(input("Enter the date:\n"))

Day_of_the_week=input("Enter the day : Monday,Tuesday,Wednesday,Thursday,Friday,Saturday,Sunday")
Day_of_the_week=int(le_day.transform([[Day_of_the_week]]))

CarCount=int(input("Enter the CarCount:\n"))

BikeCount=int(input("Enter the BikeCount:\n"))

BusCount=int(input("Enter the BusCount:\n"))

TruckCount=int(input("Enter the TruckCount:\n"))
# Out:
# Enter the date:
# 3
# Enter the day : Monday,Tuesday,Wednesday,Thursday,Friday,Saturday,SundayMonday
# C:\Users\Dell\anaconda3\Lib\site-packages\sklearn\preprocessing\_label.py:134: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# Enter the CarCount:
# 3
# Enter the BikeCount:
# 4
# Enter the BusCount:
# 5
# Enter the TruckCount:
# 6

# %%
model.predict([[Date,Day_of_the_week,CarCount,BikeCount,BusCount,TruckCount]])
# Out:
# C:\Users\Dell\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# array(['low'], dtype=object)
